# %% [markdown]
# # Introduction to Neural Networks
# Quick intro on deeplearning: Deeplearning is a subset of machine learning which has been popularized in tha past few years. There are a few things in perticular which has lead to the advancement of Deep learning
# - New computational power
# - The amount of data available
# - Powerful algorithms

# %% [markdown]
# ## Logistic Regression
# Lets go back to logistic regression.
# **goal 1** Find cats in image { 1 -> presence of a cat; 0 -> absence of a cat}.
#
# ![Diagram2.png](attachment:Diagram2.png)
#
# The shape of x = (64, 64, 3, 1) = 12,288
# To train such a model we would need images of cats along with labels.
#
# Once we have this model we have to train it.
# 1. We initialize weights (w) and bias (b).
# 2. Then we find the optimal w and b
#     - We define a loss function $L = -[ylog(y^) + (lambda-y)log(lambda-y^)]$
#     - Then we use gradient decent to minimize the function.
# 3. We will used the optimized model y = simga(wx +b) to predict

# %% [markdown]
# ## Equations
# Lets define a few equations that will help us understand neural networks.
#
# 1. $$ Neuron = Linear + Activation $$
# 2. $$ Model = Architecture + Parameters $$

# %% [markdown]
# **goal 2** Find/cat/lion/iguana in images
#
# ![Diagram3.png](attachment:Diagram3.png)
#
# The square bracket defined in the circle represents the index of the layer. [1] is the first layer. We have three times the number of parameters for the cat problem we saw in **goal 1**.
#
# To train such a model we need a dataset with images of all of the classes (cats, lions, iguanas) along with which object is present in the image represented in a vector form [1,0,0] = cat
#
# Lets define the loss function for this one layer case. $$ L3w = summation(yk log(yhatk) + (lambda-yk)log(lambda-yhatk) $$
#
# In this single layer architecture, each neuron will be responsible for a certain class (cats, lions, iguanas). This type of network is also robust for finding multiple classes since each neuron will be trained independently from each other.

# %% [markdown]
# We could also introduce connections between the neurons.
#
# **goal 3** We will now add a constraint that there is atmost one animal on an image.
#
# ![Diagram4.png](attachment:Diagram4.png)
#
# Here we use a **softmax equation** and instead of getting a probabilistic output for each class we will get a probability output over the distribution. Here we would label it like [1,0,0] cat; [0,1,0] lion; [0,0,1]iguana. We assume that there is always one class in each picture.
#
# Lets define a cross-entropy loss $$ L = -summation(yk log(yhatk) $$

# %% [markdown]
# ## Neural Netowrks
# **goal 1** given image => cat vs no cat
#
# Remember the output layer has to have the same number of neurons as the number of classes.
#
# ![Diagram5.png](attachment:Diagram5.png)

# %% [markdown]
# ### Propogation Equations
# ![Diagram6.png](attachment:Diagram6.png)

# %% [markdown]
# ### Optimization Problem
# We will be looing at forward propogation. We define a loss/cost function.
# ![Diagram7.png](attachment:Diagram7.png)
#
# So now that we have defined our loss function we have to optimize it. This is called backward propogation. Its called backward propogation because we start with the top layer and then derive the loss function and then move down the layers.

# %% [markdown]
# ## Non-linear hypotheses
# Suppose you have a non-linear classification problem and you try to use logistic regression to classify the dataset. You end up getting 1000s of features since it becomes a very high degree polynomial.
#
# One example where we see a ton of n features is in computer vision.

# %% [markdown]
# ## Neurons and the brain
# **Origins:** Algorithms that try to mimic the brain.
# **Recent resurgence:** New technology has sparked up neural networks once again.

# %% [markdown]
# ![Diagram8-2.png](attachment:Diagram8-2.png)

# %% [markdown]
# ## Model representation I
#
# Input wires -> Dendrite
# Output wires -> Axons
#
# In a simple representation, a neuron gets inputs through the dendrite performs some operations on it and then sends outputs through the axons to other parts of the brain.
